# %% [markdown]
# Customer churn prediction is to measure why customers are leaving a business. In this tutorial we will be looking at customer churn in telecom business. We will build a deep learning model to predict the churn and use precision,recall, f1-score to measure performance of our model

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4472  9541-ZPSEA    Male              0     Yes        Yes      68
# 3437  2746-DIJLO  Female              0      No         No      41
# 4     9237-HQITU  Female              0      No         No       2
# 5433  7879-CGSFV    Male              0      No         No      55
# 2493  8622-ZLFKO  Female              0     Yes         No       6
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4472          Yes            No     Fiber optic            Yes  ...
# 3437          Yes           Yes             DSL             No  ...
# 4             Yes            No     Fiber optic             No  ...
# 5433          Yes            No     Fiber optic            Yes  ...
# 2493          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 4472              Yes          No          No              No        Two year
# 3437               No          No          No              No        One year
# 4                  No          No          No              No  Month-to-month
# 5433               No          No         Yes             Yes        One year
# 2493               No          No          No             Yes  Month-to-month
#
#      PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 4472               No  Credit card (automatic)          80.35       5375.15
# 3437              Yes  Credit card (automatic)          56.30          2364
# 4                 Yes         Electronic check          70.70        151.65
# 5433              Yes             Mailed check         100.90       5552.05
# 2493              Yes         Electronic check          90.75        512.25
#
#      Churn
# 4472    No
# 3437    No
# 4      Yes
# 5433    No
# 2493    No
#
# [5 rows x 21 columns]

# %%
# droping customer ID

df.drop('customerID',axis='columns',inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# changing TotalCharges into float from object

df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File A:\New folder (2)\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# File A:\New folder (2)\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# File A:\New folder (2)\lib\site-packages\pandas\_libs\lib.pyx:2411, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (7032, 20)

# %%
# remove rows with spaces 
df1=df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\pvajs\AppData\Local\Temp\ipykernel_28296\695980592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges=pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %% [markdown]
# ## Data Visualization

# %%
tenure_churn_no=df1[df1.Churn=='No'].tenure
tenure_churn_yes=df1[df1.Churn=='Yes'].tenure

plt.xlabel('tenure')
plt.ylabel('Number of Customer')
plt.title('Customer Churn Prediction Visualization')

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes,tenure_churn_no],rwidth=0.95,color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_col_values(df):
    for column in df:
        if df[column].dtypes=='object':
            print(f'{column}:{df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No phone service' 'No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes' 'No internet service']
# OnlineBackup:['Yes' 'No' 'No internet service']
# DeviceProtection:['No' 'Yes' 'No internet service']
# TechSupport:['No' 'Yes' 'No internet service']
# StreamingTV:['No' 'Yes' 'No internet service']
# StreamingMovies:['No' 'Yes' 'No internet service']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\pvajs\AppData\Local\Temp\ipykernel_28296\3442114832.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# C:\Users\pvajs\AppData\Local\Temp\ipykernel_28296\3442114832.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender:['Female' 'Male']
# Partner:['Yes' 'No']
# Dependents:['No' 'Yes']
# PhoneService:['No' 'Yes']
# MultipleLines:['No' 'Yes']
# InternetService:['DSL' 'Fiber optic' 'No']
# OnlineSecurity:['No' 'Yes']
# OnlineBackup:['Yes' 'No']
# DeviceProtection:['No' 'Yes']
# TechSupport:['No' 'Yes']
# StreamingTV:['No' 'Yes']
# StreamingMovies:['No' 'Yes']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaperlessBilling:['Yes' 'No']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn:['No' 'Yes']

# %%
# converting Yes and No 1 or 0


yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes':1,'No':0},inplace=True)
# Out:
# C:\Users\pvajs\AppData\Local\Temp\ipykernel_28296\2695798808.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1,'No':0},inplace=True)

# %%
for col in df1:
    print(f'{col}:{df1[col].unique}')
# Out:
# gender:<bound method Series.unique of 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7032, dtype: object>
# SeniorCitizen:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: SeniorCitizen, Length: 7032, dtype: int64>
# Partner:<bound method Series.unique of 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    0
# Name: Partner, Length: 7032, dtype: int64>
# Dependents:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    0
# 7042    0
# Name: Dependents, Length: 7032, dtype: int64>
# tenure:<bound method Series.unique of 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7032, dtype: int64>
# PhoneService:<bound method Series.unique of 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    1
# 7042    1
# Name: PhoneService, Length: 7032, dtype: int64>
# MultipleLines:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    1
# 7042    0
# Name: MultipleLines, Length: 7032, dtype: int64>
# InternetService:<bound method Series.unique of 0               DSL
# 1               DSL
# 2               DSL
# 3               DSL
# 4       Fiber optic
#            ...
# 7038            DSL
# 7039    Fiber optic
# 7040            DSL
# 7041    Fiber optic
# 7042    Fiber optic
# Name: InternetService, Length: 7032, dtype: object>
# OnlineSecurity:<bound method Series.unique of 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 7038    1
# 7039    0
# 7040    1
# 7041    0
# 7042    1
# Name: OnlineSecurity, Length: 7032, dtype: int64>
# OnlineBackup:<bound method Series.unique of 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    1
# 7040    0
# 7041    0
# 7042    0
# Name: OnlineBackup, Length: 7032, dtype: int64>
# DeviceProtection:<bound method Series.unique of 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    0
# 7042    1
# Name: DeviceProtection, Length: 7032, dtype: int64>
# TechSupport:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 7038    1
# 7039    0
# 7040    0
# 7041    0
# 7042    1
# Name: TechSupport, Length: 7032, dtype: int64>
# StreamingTV:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    0
# 7042    1
# Name: StreamingTV, Length: 7032, dtype: int64>
# StreamingMovies:<bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    0
# 7041    0
# 7042    1
# Name: StreamingMovies, Length: 7032, dtype: int64>
# Contract:<bound method Series.unique of 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7032, dtype: object>
# PaperlessBilling:<bound method Series.unique of 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    1
# Name: PaperlessBilling, Length: 7032, dtype: int64>
# PaymentMethod:<bound method Series.unique of 0                Electronic check
# 1                    Mailed check
# 2                    Mailed check
# 3       Bank transfer (automatic)
# 4                Electronic check
#                   ...
# 7038                 Mailed check
# 7039      Credit card (automatic)
# 7040             Electronic check
# 7041                 Mailed check
# 7042    Bank transfer (automatic)
# Name: PaymentMethod, Length: 7032, dtype: object>
# MonthlyCharges:<bound method Series.unique of 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7032, dtype: float64>
# TotalCharges:<bound method Series.unique of 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64>
# Churn:<bound method Series.unique of 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64>

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# C:\Users\pvajs\AppData\Local\Temp\ipykernel_28296\698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ## One Hot Encoding for Categorical columns

# %%
df2=pd.get_dummies(data=df1,columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5259       0              1        1           0      30             1
# 952        0              0        0           0      22             1
# 996        1              0        0           0      34             1
# 152        1              0        1           1      70             1
# 3949       1              0        0           1      18             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5259              1               0             0                 0  ...
# 952               0               1             0                 0  ...
# 996               0               0             0                 0  ...
# 152               1               1             1                 1  ...
# 3949              1               1             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5259                    0                            1                   0
# 952                     1                            0                   0
# 996                     0                            1                   0
# 152                     0                            1                   0
# 3949                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5259                        1                  0                  0
# 952                         1                  0                  0
# 996                         1                  0                  0
# 152                         0                  1                  0
# 3949                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5259                                        0
# 952                                         0
# 996                                         0
# 152                                         0
# 3949                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5259                                      0                               0
# 952                                       0                               0
# 996                                       1                               0
# 152                                       1                               0
# 3949                                      0                               0
#
#       PaymentMethod_Mailed check
# 5259                           1
# 952                            1
# 996                            0
# 152                            0
# 3949                           1
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale=['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
df2[cols_to_scale]=scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}:{df2[col].unique()}')
# Out:
# gender:[1 0]
# SeniorCitizen:[0 1]
# Partner:[1 0]
# Dependents:[0 1]
# tenure:[0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService:[0 1]
# MultipleLines:[0 1]
# OnlineSecurity:[0 1]
# OnlineBackup:[1 0]
# DeviceProtection:[0 1]
# TechSupport:[0 1]
# StreamingTV:[0 1]
# StreamingMovies:[0 1]
# PaperlessBilling:[1 0]
# MonthlyCharges:[0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges:[0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn:[0 1]
# InternetService_DSL:[1 0]
# InternetService_Fiber optic:[0 1]
# InternetService_No:[0 1]
# Contract_Month-to-month:[1 0]
# Contract_One year:[0 1]
# Contract_Two year:[0 1]
# PaymentMethod_Bank transfer (automatic):[0 1]
# PaymentMethod_Credit card (automatic):[0 1]
# PaymentMethod_Electronic check:[1 0]
# PaymentMethod_Mailed check:[0 1]

# %% [markdown]
# ## Splitting the dataset

# %%
X=df2.drop('Churn',axis='columns')
y=df2['Churn']

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %% [markdown]
# ## Build a model(ANN)

# %%
import tensorflow as tf
from tensorflow import keras

model= keras.Sequential([
    keras.layers.Dense(26,input_shape=(26,),activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5130 - accuracy: 0.7348
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4249 - accuracy: 0.7982
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8014
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4139 - accuracy: 0.8057
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4130 - accuracy: 0.8032
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8096
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8075
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8092
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8085
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4056 - accuracy: 0.8089
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8128
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8105
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8092
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8139
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4008 - accuracy: 0.8126
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8130
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8105
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8130
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8148
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3968 - accuracy: 0.8142
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8140
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8116
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8140
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8151
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8156
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3924 - accuracy: 0.8151
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3911 - accuracy: 0.8174
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8160
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8192
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8165
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8178
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8185
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8180
# Epoch 34/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3856 - accuracy: 0.8212
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8183
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8190
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8204
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8201
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8187
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8206
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8213
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8206
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8222
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8213
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.8199
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8236
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8199
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8224
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8245
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8222
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8252
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8224
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8203
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8251
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8268
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8254
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8231
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8277
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8254
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8256
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8274
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8235
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3682 - accuracy: 0.8267
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8277
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8268
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8268
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.8270
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3658 - accuracy: 0.8276
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3662 - accuracy: 0.8286
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8272
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8272
# Epoch 72/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8270
# Epoch 73/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8272
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8276
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8276
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8293
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8334
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8247
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8297
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8292
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8290
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3604 - accuracy: 0.8252
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.8306
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8306
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.8286
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3590 - accuracy: 0.8306
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3579 - accuracy: 0.8302
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8297
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8336
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8336
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8284
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8322
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8325
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8320
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8345
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8315
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8320
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8331
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8329
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.8320

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4813 - accuracy: 0.7655
# [0.4812553822994232, 0.7654584050178528]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.3281005 ],
#        [0.35437247],
#        [0.00565841],
#        [0.71863073],
#        [0.47213462]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 0, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       999
#            1       0.62      0.50      0.56       408
#
#     accuracy                           0.77      1407
#    macro avg       0.71      0.69      0.70      1407
# weighted avg       0.76      0.77      0.76      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1407,)
